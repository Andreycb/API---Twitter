# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Andrey\\Desktop\\API - twitter\\TwitterBrasil.csv')
df
# Out:
#      Unnamed: 0              id_user  \
# 0             0            274250044
# 1             1  1074501875691634688
# 2             2   849720688235642885
# 3             3   780789968314601472
# 4             4  1300520457783967746
# ..          ...                  ...
# 622         622   931739644173176832
# 623         623  1075378187738189824
# 624         624  1211802757906042880
# 625         625            219201849
# 626         626           2845928843
#
#                                                  texto           plataforma  \
# 0    Interessados, chamar na DM, tá valendo!!! http...   Twitter for iPhone
# 1    só pra deixar claro.\n\noppa (오빠) - homem mais...      Twitter Web App
# 2                      @10xpat nossa SIM!!!,@&amp;!*!!  Twitter for Android
# 3    Amiga, diploma eu ganhei vários como melhor al...  Twitter for Android
# 4                        @finehlwalls já me sinto best  Twitter for Android
# ...

# %%
df['plataforma'].value_counts(normalize=True).plot(kind ='barh', title='Dispositivos mais usados Pt-Br')

# %%
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.texto)
word_count = pd.DataFrame(cv.get_feature_names(), columns=["texto"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:60]
# Out:
#     texto  count
# 0      co    167
# 1   https    166
# 2      de    147
# 3     que    143
# 4      eu    128
# 5     não     88
# 6     com     70
# 7     pra     58
# 8      um     56
# 9      do     54
# 10    meu     51
# 11     no     44
# 12     me     40
# 13     se     37
# 14     da     36
# 15     na     36
# 16    vai     34
# 17    mas     32
# 18    uma     32
# 19   mais     30
# 20  minha     29
# 21    tem     27
# 22     em     27
# 23    por     26
# 24     vc     25
# 25   isso     22
# 26     os     22
# 27     só     21
# 28     gt     21
# 29    até     21
# 30    foi     21
# 31  muito     20
# 32    ele     19
# 33     tá     19
# 34     já     19
# 35    ela     18
# 36    vou     18
# 37  fazer     18
# 38   você     18
# 39   esse     18
# 40   para     17
# 41   essa     17
# 42    dia     17
# 43    ser     16
# 44  tenho     15
# 45    são     15
# 46     to     15
# 47   tudo     15
# 48    seu     15
# 49  gente     15
# 50   como     14
# ...
